# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objs as go

# %%
df=pd.read_csv('country_wise_latest.csv')

# %%
df.head()
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %%
df.shape
# Out:
# (187, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country/Region          187 non-null    object
#  1   Confirmed               187 non-null    int64
#  2   Deaths                  187 non-null    int64
#  3   Recovered               187 non-null    int64
#  4   Active                  187 non-null    int64
#  5   New cases               187 non-null    int64
#  6   New deaths              187 non-null    int64
#  7   New recovered           187 non-null    int64
#  8   Deaths / 100 Cases      187 non-null    float64
#  9   Recovered / 100 Cases   187 non-null    float64
#  10  Deaths / 100 Recovered  187 non-null    float64
#  11  Confirmed last week     187 non-null    int64
#  12  1 week change           187 non-null    int64
#  13  1 week % increase       187 non-null    float64
# ...

# %%
df.columns
# Out:
# Index(['Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'New cases', 'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered',
#        'Confirmed last week', '1 week change', '1 week % increase',
#        'WHO Region'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# Country/Region            0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New cases                 0
# New deaths                0
# New recovered             0
# Deaths / 100 Cases        0
# Recovered / 100 Cases     0
# Deaths / 100 Recovered    0
# Confirmed last week       0
# 1 week change             0
# 1 week % increase         0
# WHO Region                0
# dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df.describe().T,cbar=False,cmap="tab20",annot=True,vmin=30,vmax=70,linewidths=2,linecolor='yellow',fmt='.2f')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=df,x='WHO Region',y='Deaths',hue='WHO Region')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(data=df,x='WHO Region',y='Recovered',hue='WHO Region')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(data=df,x='WHO Region',y='Confirmed',hue='WHO Region')
plt.show()

# %%
x=np.array([1,2,3])
y=np.array([4,5,6])
np.meshgrid(x,y)
xx,yy=np.meshgrid(x,y)

# %%
xx
# Out:
# array([[1, 2, 3],
#        [1, 2, 3],
#        [1, 2, 3]])

# %%
yy
# Out:
# array([[4, 4, 4],
#        [5, 5, 5],
#        [6, 6, 6]])

# %%
xx.shape,yy.shape
# Out:
# ((3, 3), (3, 3))

# %%
z=np.random.random((3,3))
z.shape
# Out:
# (3, 3)

# %%
plt.figure(figsize=(12,6))
plt.contourf(xx,yy,z)
